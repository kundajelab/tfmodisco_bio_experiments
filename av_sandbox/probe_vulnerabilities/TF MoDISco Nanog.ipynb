# %% [markdown]
# # TF-MoDISco on the Nanog GkmExplain Scores
#
# This notebook demonstrates running TF-MoDISco on importance scores obtained from gkmexplain on Nanog ChIP-seq data in H1ESCs. See `Generate Importance Scores.ipynb` for a notebook demonstrating how to produce the scores.

# %%
from __future__ import print_function, division
# %matplotlib inline

try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3

# %%
import numpy as np
import modisco
import sys
print (sys.version)
import os
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# 2.7.12 |Anaconda 2.1.0 (x86_64)| (default, Jul  2 2016, 17:43:17)
# [GCC 4.2.1 (Based on Apple Inc. build 5658) (LLVM build 2336.11.00)]
# TF-MoDISco is using the TensorFlow backend.

# %% [markdown]
# ## Grab the input data

# %%
# !wget https://raw.githubusercontent.com/AvantiShri/model_storage/2e603c/modisco/gkmexplain_scores/positives_test.fa.gz -O positives_test.fa.gz
# !gunzip positives_test.fa.gz 
# !wget https://raw.githubusercontent.com/AvantiShri/model_storage/2e603c/modisco/gkmexplain_scores/gkmexplain_positives_impscores.txt.gz -O gkmexplain_positives_impscores.txt.gz
# !gunzip gkmexplain_positives_impscores.txt.gz
# !wget https://raw.githubusercontent.com/AvantiShri/model_storage/2e603c/modisco/gkmexplain_scores/gkmexplain_positives_hypimpscores.txt.gz -O gkmexplain_positives_hypimpscores.txt.gz
# !gunzip gkmexplain_positives_hypimpscores.txt.gz
# !wget https://raw.githubusercontent.com/AvantiShri/model_storage/c8ebc38/modisco/gkmexplain_scores/gkmexplain_dnshuff_impscores.txt.gz -O gkmexplain_dnshuff_impscores.txt.gz
# !gunzip gkmexplain_dnshuff_impscores.txt.gz
# Out:
# --2019-02-13 14:54:30--  https://raw.githubusercontent.com/AvantiShri/model_storage/2e603c/modisco/gkmexplain_scores/positives_test.fa.gz
# Resolving raw.githubusercontent.com... 151.101.196.133
# Connecting to raw.githubusercontent.com|151.101.196.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75038 (73K) [application/octet-stream]
# Saving to: 'positives_test.fa.gz'
#
# 100%[======================================>] 75,038      --.-K/s   in 0.05s
#
# 2019-02-13 14:54:31 (1.52 MB/s) - 'positives_test.fa.gz' saved [75038/75038]
#
# --2019-02-13 14:54:31--  https://raw.githubusercontent.com/AvantiShri/model_storage/2e603c/modisco/gkmexplain_scores/gkmexplain_positives_impscores.txt.gz
# Resolving raw.githubusercontent.com... 151.101.196.133
# Connecting to raw.githubusercontent.com|151.101.196.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1000384 (977K) [application/octet-stream]
# Saving to: 'gkmexplain_positives_impscores.txt.gz'
#
# 100%[======================================>] 1,000,384   3.67MB/s   in 0.3s
#
# 2019-02-13 14:54:32 (3.67 MB/s) - 'gkmexplain_positives_impscores.txt.gz' saved [1000384/1000384]
#
# --2019-02-13 14:54:32--  https://raw.githubusercontent.com/AvantiShri/model_storage/2e603c/modisco/gkmexplain_scores/gkmexplain_positives_hypimpscores.txt.gz
# Resolving raw.githubusercontent.com... 151.101.196.133
# Connecting to raw.githubusercontent.com|151.101.196.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3191036 (3.0M) [application/octet-stream]
# Saving to: 'gkmexplain_positives_hypimpscores.txt.gz'
#
# 100%[======================================>] 3,191,036   1.01MB/s   in 3.0s
#
# 2019-02-13 14:54:35 (1.01 MB/s) - 'gkmexplain_positives_hypimpscores.txt.gz' saved [3191036/3191036]
#
# --2019-02-13 14:54:36--  https://raw.githubusercontent.com/AvantiShri/model_storage/c8ebc38/modisco/gkmexplain_scores/gkmexplain_dnshuff_impscores.txt.gz
# Resolving raw.githubusercontent.com... 151.101.196.133
# Connecting to raw.githubusercontent.com|151.101.196.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 518999 (507K) [application/octet-stream]
# Saving to: 'gkmexplain_dnshuff_impscores.txt.gz'
#
# 100%[======================================>] 518,999     1.77MB/s   in 0.3s
#
# 2019-02-13 14:54:36 (1.77 MB/s) - 'gkmexplain_dnshuff_impscores.txt.gz' saved [518999/518999]

# %% [markdown]
# ### Read in the one-hot encoded sequences and scores

# %%
import numpy as np

def one_hot_encode_along_channel_axis(sequence):
    to_return = np.zeros((len(sequence),4), dtype=np.int8)
    seq_to_one_hot_fill_in_array(zeros_array=to_return,
                                 sequence=sequence, one_hot_axis=1)
    return to_return

def seq_to_one_hot_fill_in_array(zeros_array, sequence, one_hot_axis):
    assert one_hot_axis==0 or one_hot_axis==1
    if (one_hot_axis==0):
        assert zeros_array.shape[1] == len(sequence)
    elif (one_hot_axis==1): 
        assert zeros_array.shape[0] == len(sequence)
    #will mutate zeros_array
    for (i,char) in enumerate(sequence):
        if (char=="A" or char=="a"):
            char_idx = 0
        elif (char=="C" or char=="c"):
            char_idx = 1
        elif (char=="G" or char=="g"):
            char_idx = 2
        elif (char=="T" or char=="t"):
            char_idx = 3
        elif (char=="N" or char=="n"):
            continue #leave that pos as all 0's
        else:
            raise RuntimeError("Unsupported character: "+str(char))
        if (one_hot_axis==0):
            zeros_array[char_idx,i] = 1
        elif (one_hot_axis==1):
            zeros_array[i,char_idx] = 1
            
#read in the fasta files and one-hot encode
fasta_seqs = [x.rstrip() for (i,x) in enumerate(open("positives_test.fa"))
              if i%2==1]
#filter out any sequences that contain 'N's
onehot_data = [np.array(one_hot_encode_along_channel_axis(x))
                         for x in fasta_seqs if ('N' not in x)]
print("Num onehot sequences:",len(onehot_data))

#read in the importance scores and hypothetical importance scores
#filter out any sequences that contain 'N's
hyp_impscores = [w[0] for w in zip([
    np.array( [[float(z) for z in y.split(",")] for y in x.rstrip().split("\t")[2].split(";")])
    for x in open("gkmexplain_positives_hypimpscores.txt")
],fasta_seqs) if 'N' not in w[1]]

impscores = [w[0] for w in zip([
    np.array( [[float(z) for z in y.split(",")] for y in x.rstrip().split("\t")[2].split(";")])
    for x in open("gkmexplain_positives_impscores.txt")
],fasta_seqs) if 'N' not in w[1]]

#Perform a sanity check to make sure that the importance score are the same as the
# hypothetical scores multiplied elementwise with the one-hot encoding; for this
# reason, it is not technically necessary to compute the importance scores if the
# hypothetical scores are also computed
assert (np.max([np.max(np.abs(z*y - x)) for x,y,z in zip(impscores,onehot_data,hyp_impscores)]))==0

#Read in scores on the dinucleotide-shuffled sequences, taking
# the sum across ACGT at each position, to get an empirical null distribution
# of per-position importance scores
nulldist_perposimp = [
    np.array( [sum([float(z) for z in y.split(",")]) for
                y in x.rstrip().split("\t")[2].split(";")])
    for x in open("gkmexplain_dnshuff_impscores.txt")]
# Out:
# Num onehot sequences: 960

# %% [markdown]
# Double check by plotting

# %%
from matplotlib import pyplot as plt
import modisco.visualization
from modisco.visualization import viz_sequence

viz_sequence.plot_weights(impscores[0], subticks_frequency=10)
viz_sequence.plot_weights(hyp_impscores[0], subticks_frequency=10)
viz_sequence.plot_weights(onehot_data[0], subticks_frequency=10)

# %% [markdown]
# ## Run TF-MoDISco
#
# To demonstrate customization, the code below has slight modifications from default settings in the following ways:
# - An empirical null distribution is supplied for per-position importance scores using the argument `null_per_pos_scores`
# - `target_seqlet_fdr` controls the noisiness of the seqlets. For a particular task, importance scores are first smoothed with a window of size `sliding_window_size` (default value of 21 at the time of writing), and the FDR for scores in sliding windows is estimated using the supplied empirical null distribution. This is used to set a threshold on sliding windows that can go on to form seqlets. Note: if the number of sliding windows that pass the FDR threshold is smaller than `min_passing_windows_frac` (default value 0.03 at the time of writing) or larger than `max_passing_windows_frac` (default value of 0.2 at the time of writing), the threshold will be adjusted.
# - The code below uses kmers of length 5 with 1 gap and no mismatches to compute the "quick and dirty" affinity matrix across all seqlets. The "quick and dirty" affinity matrix is used both for noise filtering and as a first pass to speed up computation of the continuous jaccard affinity matrix (the latter affinities are only computed between seqlets deemed to be close together by the "quick and dirty" method). I made the kmer length smaller to keep memory usage on the GPU down when testing on my macbook pro. The default is to use kmers of length 8 with 3 gaps and 2 mismatches, and this works fine on more modern GPUs than the one in my 4-year-old macbook.

# %%
import h5py
import numpy as np
# %matplotlib inline
import modisco
reload(modisco)
import modisco.backend
reload(modisco.backend.tensorflow_backend)
reload(modisco.backend)
import modisco.nearest_neighbors
reload(modisco.nearest_neighbors)
import modisco.affinitymat
reload(modisco.affinitymat.core)
reload(modisco.affinitymat.transformers)
import modisco.tfmodisco_workflow.seqlets_to_patterns
reload(modisco.tfmodisco_workflow.seqlets_to_patterns)
import modisco.tfmodisco_workflow.workflow
reload(modisco.tfmodisco_workflow.workflow)
import modisco.aggregator
reload(modisco.aggregator)
import modisco.cluster
reload(modisco.cluster.core)
reload(modisco.cluster.phenograph.core)
reload(modisco.cluster.phenograph.cluster)
import modisco.value_provider
reload(modisco.value_provider)
import modisco.core
reload(modisco.core)
import modisco.coordproducers
reload(modisco.coordproducers)
import modisco.metaclusterers
reload(modisco.metaclusterers)

tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                        target_seqlet_fdr=0.2,
                        seqlets_to_patterns_factory=
                            modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                                #Adjust trim_to_window_size and initial_flank_to_add
                                # according to how big you expect
                                # the core motif to be; default value is 10
                                #trim_to_window_size=6,
                                #initial_flank_to_add=2,
                                #final_flank_to_add=5,
                                #kmer_len, num_gaps and num_mismatches are used to
                                # derive kmer embeddings for coarse-grained affinity
                                # matrix calculation. kmer_len=6, num_gaps=1
                                # and num_mismatches=0 means
                                # that kmer embeddings using 6-mers with 1 gap will be
                                # used.
                                kmer_len=6, num_gaps=1,
                                num_mismatches=0,
                                final_min_cluster_size=20,
                                min_num_to_trim_to=20,
                        ),
                   )(
                #There is only one task, so we just call this 'task0'
                task_names=["task0"],
                contrib_scores={'task0': impscores},                
                hypothetical_contribs={'task0': hyp_impscores},
                one_hot=onehot_data,
                null_per_pos_scores={'task0': nulldist_perposimp})
# Out:
# On task task0
# Computing windowed sums on original
# Generating null dist
# Computing threshold
# Thresholds from null dist were -0.3373419  and  0.29233143999999983
# Final raw thresholds are -0.3373419  and  0.29233143999999983
# Final transformed thresholds are -0.954056712962963  and  0.9289004629629629
# TF-MoDISco is using the TensorFlow backend.
# Got 807 coords
# After resolving overlaps, got 807 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.928900362962963
# 807 identified in total
# 1 activity patterns with support >= 100 out of 3 possible patterns
# Metacluster sizes:  [771]
# Idx to activities:  {0: '1'}
# On metacluster 0
# Metacluster size 771
# Relevant tasks:  ('task0',)
# Relevant signs:  (1,)
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 771
# (Round 1) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 0.91 s
# Starting affinity matrix computations
# Normalization computed in 0.03 s
# Cosine similarity mat computed in 0.06 s
# Normalization computed in 0.02 s
# Cosine similarity mat computed in 0.06 s
# Finished affinity matrix computations in 0.13 s
# (Round 1) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.04 s
# (Round 1) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 18.92 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 21.9 s
# (Round 1) Computed affinity matrix on nearest neighbors in 42.42 s
# Filtered down to 747 of 771
# (Round 1) Retained 747 rows out of 771 after filtering
# (Round 1) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 747 samples in 0.000s...
# [t-SNE] Computed neighbors for 747 samples in 0.010s...
# [t-SNE] Computed conditional probabilities for sample 747 / 747
# [t-SNE] Mean sigma: 0.237331
# (Round 1) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0522727966309 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=4)]: Done 144 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    3.4s finished
# Louvain completed 200 runs in 4.03665995598 seconds
# Wrote graph to binary file in 0.231684207916 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.64932
# After 35 runs, maximum modularity is Q = 0.652638
# Louvain completed 85 runs in 2.59788799286 seconds
# Preproc + Louvain took 6.99566411972 s
# Got 6 clusters after round 1
# Counts:
# {0: 218, 1: 180, 2: 165, 3: 92, 4: 80, 5: 12}
# (Round 1) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 218 seqlets
# Trimmed 5 out of 218
# Skipped 22 seqlets
# Aggregating for cluster 1 with 180 seqlets
# Trimmed 9 out of 180
# Skipped 22 seqlets
# Aggregating for cluster 2 with 165 seqlets
# Trimmed 26 out of 165
# Skipped 22 seqlets
# Aggregating for cluster 3 with 92 seqlets
# Trimmed 5 out of 92
# Skipped 17 seqlets
# Aggregating for cluster 4 with 80 seqlets
# Trimmed 0 out of 80
# Skipped 17 seqlets
# Aggregating for cluster 5 with 12 seqlets
# Trimmed 0 out of 12
# Skipped 4 seqlets
# (Round 2) num seqlets: 598
# (Round 2) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 0.98 s
# Starting affinity matrix computations
# Normalization computed in 0.03 s
# Cosine similarity mat computed in 0.05 s
# Normalization computed in 0.02 s
# Cosine similarity mat computed in 0.04 s
# Finished affinity matrix computations in 0.1 s
# (Round 2) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.03 s
# (Round 2) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 24.76 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 23.87 s
# (Round 2) Computed affinity matrix on nearest neighbors in 50.16 s
# Not applying filtering for rounds above first round
# (Round 2) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 598 samples in 0.000s...
# [t-SNE] Computed neighbors for 598 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 598 / 598
# [t-SNE] Mean sigma: 0.238508
# (Round 2) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0487399101257 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=4)]: Done 144 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    3.0s finished
# Louvain completed 200 runs in 3.49135494232 seconds
# Wrote graph to binary file in 0.200974941254 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.648068
# After 6 runs, maximum modularity is Q = 0.649811
# Louvain completed 56 runs in 1.58917593956 seconds
# Preproc + Louvain took 5.39717006683 s
# Got 6 clusters after round 2
# Counts:
# {0: 174, 1: 163, 2: 133, 3: 68, 4: 33, 5: 27}
# (Round 2) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 174 seqlets
# Trimmed 9 out of 174
# Aggregating for cluster 1 with 163 seqlets
# Trimmed 33 out of 163
# Aggregating for cluster 2 with 133 seqlets
# Trimmed 3 out of 133
# Aggregating for cluster 3 with 68 seqlets
# Trimmed 16 out of 68
# Aggregating for cluster 4 with 33 seqlets
# Trimmed 2 out of 33
# Aggregating for cluster 5 with 27 seqlets
# Trimmed 2 out of 27
# Skipped 1 seqlets
# Got 6 clusters
# Splitting into subclusters...
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0340249538422 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00652894
# Louvain completed 21 runs in 0.415423870087 seconds
# Similarity is 0.9819747034405579; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0241479873657 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00564335
# After 2 runs, maximum modularity is Q = 0.00584294
# Louvain completed 22 runs in 0.439079999924 seconds
# Similarity is 0.8881228996155346; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0218179225922 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00713738
# Louvain completed 21 runs in 0.402494907379 seconds
# Similarity is 0.8479390161032461; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00595712661743 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00692648
# After 8 runs, maximum modularity is Q = 0.00692649
# Louvain completed 28 runs in 0.509536981583 seconds
# Similarity is 0.7572779632563902; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00245809555054 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0040704
# Louvain completed 21 runs in 0.368376970291 seconds
# Similarity is 0.842914641940544; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00257992744446 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00397223
# Louvain completed 21 runs in 0.3667781353 seconds
# Similarity is 0.6070428297150001; is_dissimilar is True
# Got 3 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00312495231628 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00444009
# Louvain completed 21 runs in 0.370945215225 seconds
# Similarity is 0.8817360098416333; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0020809173584 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00659361
# After 10 runs, maximum modularity is Q = 0.00659362
# Louvain completed 30 runs in 0.495002985001 seconds
# Similarity is 0.40729974034474536; is_dissimilar is True
# Got 2 subclusters
# Merging on 9 clusters
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 9 patterns after merging
# Performing seqlet reassignment
# Cross contin jaccard time taken: 0.28 s
# Cross contin jaccard time taken: 0.28 s
# Skipped 14 seqlets
# Skipped 3 seqlets
# Skipped 8 seqlets
# Skipped 2 seqlets
# Skipped 5 seqlets
# Got 5 patterns after reassignment
# Total time taken is 120.69s

# %%
from modisco.visualization import viz_sequence
from modisco.aggregator import TrimToBestWindow

pattern_merge_hierarchy = (tfmodisco_results.metacluster_idx_to_submetacluster_results[0]
                           .seqlets_to_patterns_result.pattern_merge_hierarchy)
for node in pattern_merge_hierarchy.root_nodes:
    pattern = node.pattern.trim_to_positions_with_min_support(0.2, 20)
    background = np.array([0.25, 0.25, 0.25, 0.25])
    print(len(pattern.seqlets))
    viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"].fwd),
                                                    background=background))
    viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"].rev),
                                                    background=background))
# Out:
# Trimmed 10 out of 178
# 168
# Trimmed 10 out of 140
# 130
# Trimmed 8 out of 138
# 130
# Trimmed 6 out of 43
# 37
# Trimmed 0 out of 14
# 14
# Trimmed 0 out of 10
# 10
# Trimmed 2 out of 33
# 31
# Trimmed 0 out of 13
# 13
# Trimmed 0 out of 11
# 11

# %%
import h5py
import numpy as np
# %matplotlib inline
import modisco
reload(modisco)
import modisco.backend
reload(modisco.backend.tensorflow_backend)
reload(modisco.backend)
import modisco.nearest_neighbors
reload(modisco.nearest_neighbors)
import modisco.affinitymat
reload(modisco.affinitymat.core)
reload(modisco.affinitymat.transformers)
import modisco.tfmodisco_workflow.seqlets_to_patterns
reload(modisco.tfmodisco_workflow.seqlets_to_patterns)
import modisco.tfmodisco_workflow.workflow
reload(modisco.tfmodisco_workflow.workflow)
import modisco.aggregator
reload(modisco.aggregator)
import modisco.cluster
reload(modisco.cluster.core)
reload(modisco.cluster.phenograph.core)
reload(modisco.cluster.phenograph.cluster)
import modisco.value_provider
reload(modisco.value_provider)
import modisco.core
reload(modisco.core)
import modisco.coordproducers
reload(modisco.coordproducers)
import modisco.metaclusterers
reload(modisco.metaclusterers)

tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                        target_seqlet_fdr=0.25,
                        seqlets_to_patterns_factory=
                            modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                                #Adjust trim_to_window_size and initial_flank_to_add
                                # according to how big you expect
                                # the core motif to be; default value is 10
                                #trim_to_window_size=6,
                                #initial_flank_to_add=2,
                                #final_flank_to_add=5,
                                #kmer_len, num_gaps and num_mismatches are used to
                                # derive kmer embeddings for coarse-grained affinity
                                # matrix calculation. kmer_len=6, num_gaps=1
                                # and num_mismatches=0 means
                                # that kmer embeddings using 6-mers with 1 gap will be
                                # used.
                                kmer_len=6, num_gaps=1,
                                num_mismatches=0,
                                final_min_cluster_size=20,
                        ),
                   )(
                #There is only one task, so we just call this 'task0'
                task_names=["task0"],
                contrib_scores={'task0': impscores},                
                hypothetical_contribs={'task0': hyp_impscores},
                one_hot=onehot_data,
                null_per_pos_scores={'task0': nulldist_perposimp})
# Out:
# On task task0
# Computing windowed sums on original
# Generating null dist
# Computing threshold
# Thresholds from null dist were -0.3263244370000001  and  0.2663503000000001
# Final raw thresholds are -0.3263244370000001  and  0.2663503000000001
# Final transformed thresholds are -0.9486284722222222  and  0.9078125
# TF-MoDISco is using the TensorFlow backend.
# Got 974 coords
# After resolving overlaps, got 974 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.9078124000000001
# 974 identified in total
# 1 activity patterns with support >= 100 out of 3 possible patterns
# Metacluster sizes:  [936]
# Idx to activities:  {0: '1'}
# On metacluster 0
# Metacluster size 936
# Relevant tasks:  ('task0',)
# Relevant signs:  (1,)
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 936
# (Round 1) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 1.11 s
# Starting affinity matrix computations
# Normalization computed in 0.04 s
# Cosine similarity mat computed in 0.09 s
# Normalization computed in 0.03 s
# Cosine similarity mat computed in 0.07 s
# Finished affinity matrix computations in 0.17 s
# (Round 1) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.05 s
# (Round 1) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 25.25 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 30.08 s
# (Round 1) Computed affinity matrix on nearest neighbors in 57.3 s
# Filtered down to 884 of 936
# (Round 1) Retained 884 rows out of 936 after filtering
# (Round 1) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 884 samples in 0.001s...
# [t-SNE] Computed neighbors for 884 samples in 0.013s...
# [t-SNE] Computed conditional probabilities for sample 884 / 884
# [t-SNE] Mean sigma: 0.237162
# (Round 1) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0680439472198 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=4)]: Done 128 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    3.7s finished
# Louvain completed 200 runs in 4.38350987434 seconds
# Wrote graph to binary file in 0.383426904678 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.646114
# After 2 runs, maximum modularity is Q = 0.646122
# After 3 runs, maximum modularity is Q = 0.647853
# After 8 runs, maximum modularity is Q = 0.64786
# After 9 runs, maximum modularity is Q = 0.661169
# After 27 runs, maximum modularity is Q = 0.661176
# Louvain completed 77 runs in 2.8224170208 seconds
# Preproc + Louvain took 7.75183105469 s
# Got 7 clusters after round 1
# Counts:
# {0: 222, 1: 192, 2: 188, 3: 134, 4: 91, 5: 45, 6: 12}
# (Round 1) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 222 seqlets
# Trimmed 13 out of 222
# Skipped 19 seqlets
# Aggregating for cluster 1 with 192 seqlets
# Trimmed 5 out of 192
# Skipped 29 seqlets
# Aggregating for cluster 2 with 188 seqlets
# Trimmed 9 out of 188
# Skipped 32 seqlets
# Aggregating for cluster 3 with 134 seqlets
# Trimmed 5 out of 134
# Skipped 21 seqlets
# Aggregating for cluster 4 with 91 seqlets
# Trimmed 4 out of 91
# Skipped 17 seqlets
# Aggregating for cluster 5 with 45 seqlets
# Trimmed 2 out of 45
# Skipped 8 seqlets
# Aggregating for cluster 6 with 12 seqlets
# Trimmed 0 out of 12
# Skipped 3 seqlets
# (Round 2) num seqlets: 717
# (Round 2) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 1.02 s
# Starting affinity matrix computations
# Normalization computed in 0.03 s
# Cosine similarity mat computed in 0.06 s
# Normalization computed in 0.02 s
# Cosine similarity mat computed in 0.05 s
# Finished affinity matrix computations in 0.12 s
# (Round 2) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.04 s
# (Round 2) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 36.76 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 37.34 s
# (Round 2) Computed affinity matrix on nearest neighbors in 76.16 s
# Not applying filtering for rounds above first round
# (Round 2) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 717 samples in 0.000s...
# [t-SNE] Computed neighbors for 717 samples in 0.011s...
# [t-SNE] Computed conditional probabilities for sample 717 / 717
# [t-SNE] Mean sigma: 0.237314
# (Round 2) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0603439807892 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    4.0s finished
# Louvain completed 200 runs in 4.75254511833 seconds
# Wrote graph to binary file in 0.326901912689 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.620051
# After 2 runs, maximum modularity is Q = 0.620056
# After 6 runs, maximum modularity is Q = 0.649999
# After 14 runs, maximum modularity is Q = 0.65084
# After 23 runs, maximum modularity is Q = 0.65235
# Louvain completed 73 runs in 2.78779101372 seconds
# Preproc + Louvain took 8.02192211151 s
# Got 5 clusters after round 2
# Counts:
# {0: 217, 1: 185, 2: 166, 3: 97, 4: 52}
# (Round 2) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 217 seqlets
# Trimmed 82 out of 217
# Aggregating for cluster 1 with 185 seqlets
# Trimmed 18 out of 185
# Aggregating for cluster 2 with 166 seqlets
# Trimmed 16 out of 166
# Aggregating for cluster 3 with 97 seqlets
# Trimmed 12 out of 97
# Skipped 2 seqlets
# Aggregating for cluster 4 with 52 seqlets
# Trimmed 9 out of 52
# Skipped 1 seqlets
# Got 5 clusters
# Splitting into subclusters...
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0269379615784 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00602516
# After 20 runs, maximum modularity is Q = 0.00603532
# Louvain completed 40 runs in 0.840004920959 seconds
# Similarity is 0.8430223585946941; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.03586602211 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00546555
# After 2 runs, maximum modularity is Q = 0.00547915
# Louvain completed 22 runs in 0.488840103149 seconds
# Similarity is 0.9856025360576772; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0282680988312 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00740214
# After 2 runs, maximum modularity is Q = 0.00855851
# Louvain completed 22 runs in 0.493098020554 seconds
# Similarity is 0.8154407227117908; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0109848976135 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00979146
# Louvain completed 21 runs in 0.406357049942 seconds
# Similarity is 0.7212009110794205; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0045108795166 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00431104
# Louvain completed 21 runs in 0.403052091599 seconds
# Similarity is 0.8281938967764507; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00301003456116 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00375425
# After 6 runs, maximum modularity is Q = 0.0041382
# After 12 runs, maximum modularity is Q = 0.00413821
# Louvain completed 32 runs in 0.59295296669 seconds
# Similarity is 0.8882159584308434; is_dissimilar is False
# Got 2 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00431799888611 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00798163
# Louvain completed 21 runs in 0.411182165146 seconds
# Similarity is 0.52735754586265; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00163698196411 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0030304
# After 3 runs, maximum modularity is Q = 0.00594019
# After 4 runs, maximum modularity is Q = 0.0059402
# After 15 runs, maximum modularity is Q = 0.00594021
# Louvain completed 35 runs in 0.652945995331 seconds
# Similarity is 0.5464414051294046; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00149917602539 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00228368
# After 2 runs, maximum modularity is Q = 0.00424907
# Louvain completed 22 runs in 0.405594110489 seconds
# Similarity is 0.654460365778971; is_dissimilar is True
# Got 3 subclusters
# Merging on 8 clusters
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 8 patterns after merging
# Performing seqlet reassignment
# Cross contin jaccard time taken: 0.27 s
# Cross contin jaccard time taken: 0.29 s
# Discarded 1 seqlets
# Skipped 3 seqlets
# Skipped 8 seqlets
# Skipped 11 seqlets
# Skipped 4 seqlets
# Skipped 2 seqlets
# Got 5 patterns after reassignment
# Total time taken is 168.11s

# %%
from modisco.visualization import viz_sequence
from modisco.aggregator import TrimToBestWindow

pattern_merge_hierarchy = (tfmodisco_results.metacluster_idx_to_submetacluster_results[0]
                           .seqlets_to_patterns_result.pattern_merge_hierarchy)
for node in pattern_merge_hierarchy.root_nodes:
    pattern = node.pattern.trim_to_positions_with_min_support(0.2, 20)
    background = np.array([0.25, 0.25, 0.25, 0.25])
    print(len(pattern.seqlets))
    viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"].fwd),
                                                    background=background))
    viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"].rev),
                                                    background=background))
# Out:
# Trimmed 6 out of 141
# 135
# Trimmed 11 out of 178
# 167
# Trimmed 1 out of 151
# 150
# Trimmed 14 out of 63
# 49
# Trimmed 6 out of 43
# 37
# Trimmed 0 out of 11
# 11
# Trimmed 0 out of 12
# 12
# Trimmed 0 out of 19
# 19

# %%
import h5py
import numpy as np
# %matplotlib inline
import modisco
reload(modisco)
import modisco.backend
reload(modisco.backend.tensorflow_backend)
reload(modisco.backend)
import modisco.nearest_neighbors
reload(modisco.nearest_neighbors)
import modisco.affinitymat
reload(modisco.affinitymat.core)
reload(modisco.affinitymat.transformers)
import modisco.tfmodisco_workflow.seqlets_to_patterns
reload(modisco.tfmodisco_workflow.seqlets_to_patterns)
import modisco.tfmodisco_workflow.workflow
reload(modisco.tfmodisco_workflow.workflow)
import modisco.aggregator
reload(modisco.aggregator)
import modisco.cluster
reload(modisco.cluster.core)
reload(modisco.cluster.phenograph.core)
reload(modisco.cluster.phenograph.cluster)
import modisco.value_provider
reload(modisco.value_provider)
import modisco.core
reload(modisco.core)
import modisco.coordproducers
reload(modisco.coordproducers)
import modisco.metaclusterers
reload(modisco.metaclusterers)

tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                        target_seqlet_fdr=0.15,
                        seqlets_to_patterns_factory=
                            modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                                #Adjust trim_to_window_size and initial_flank_to_add
                                # according to how big you expect
                                # the core motif to be; default value is 10
                                #trim_to_window_size=6,
                                #initial_flank_to_add=2,
                                #final_flank_to_add=5,
                                #kmer_len, num_gaps and num_mismatches are used to
                                # derive kmer embeddings for coarse-grained affinity
                                # matrix calculation. kmer_len=6, num_gaps=1
                                # and num_mismatches=0 means
                                # that kmer embeddings using 6-mers with 1 gap will be
                                # used.
                                kmer_len=6, num_gaps=1,
                                num_mismatches=0,
                                final_min_cluster_size=20,
                        ),
                   )(
                #There is only one task, so we just call this 'task0'
                task_names=["task0"],
                contrib_scores={'task0': impscores},                
                hypothetical_contribs={'task0': hyp_impscores},
                one_hot=onehot_data,
                null_per_pos_scores={'task0': nulldist_perposimp})
# Out:
# On task task0
# Computing windowed sums on original
# Generating null dist
# Computing threshold
# Thresholds from null dist were -0.38209123  and  0.32246728
# Final raw thresholds are -0.38209123  and  0.32246728
# Final transformed thresholds are -0.9707581018518519  and  0.9467129629629629
# TF-MoDISco is using the TensorFlow backend.
# Got 640 coords
# After resolving overlaps, got 640 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.946712862962963
# 640 identified in total
# 1 activity patterns with support >= 100 out of 3 possible patterns
# Metacluster sizes:  [622]
# Idx to activities:  {0: '1'}
# On metacluster 0
# Metacluster size 622
# Relevant tasks:  ('task0',)
# Relevant signs:  (1,)
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 622
# (Round 1) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 0.75 s
# Starting affinity matrix computations
# Normalization computed in 0.03 s
# Cosine similarity mat computed in 0.05 s
# Normalization computed in 0.02 s
# Cosine similarity mat computed in 0.04 s
# Finished affinity matrix computations in 0.1 s
# (Round 1) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.03 s
# (Round 1) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 14.71 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 17.36 s
# (Round 1) Computed affinity matrix on nearest neighbors in 33.32 s
# Filtered down to 610 of 622
# (Round 1) Retained 610 rows out of 622 after filtering
# (Round 1) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 610 samples in 0.000s...
# [t-SNE] Computed neighbors for 610 samples in 0.007s...
# [t-SNE] Computed conditional probabilities for sample 610 / 610
# [t-SNE] Mean sigma: 0.239439
# (Round 1) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0470697879791 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=4)]: Done 144 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    3.4s finished
# Louvain completed 200 runs in 3.86325001717 seconds
# Wrote graph to binary file in 0.15388417244 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.618855
# After 3 runs, maximum modularity is Q = 0.650716
# After 21 runs, maximum modularity is Q = 0.651231
# After 31 runs, maximum modularity is Q = 0.6605
# Louvain completed 81 runs in 2.17342710495 seconds
# Preproc + Louvain took 6.30514001846 s
# Got 6 clusters after round 1
# Counts:
# {0: 165, 1: 151, 2: 133, 3: 73, 4: 55, 5: 33}
# (Round 1) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 165 seqlets
# Trimmed 6 out of 165
# Skipped 14 seqlets
# Aggregating for cluster 1 with 151 seqlets
# Trimmed 7 out of 151
# Skipped 17 seqlets
# Aggregating for cluster 2 with 133 seqlets
# Trimmed 4 out of 133
# Skipped 20 seqlets
# Aggregating for cluster 3 with 73 seqlets
# Trimmed 2 out of 73
# Skipped 14 seqlets
# Aggregating for cluster 4 with 55 seqlets
# Trimmed 2 out of 55
# Skipped 10 seqlets
# Aggregating for cluster 5 with 33 seqlets
# Trimmed 0 out of 33
# Skipped 3 seqlets
# (Round 2) num seqlets: 511
# (Round 2) Computing coarse affmat
# Beginning embedding computation
# Computing embeddings
# Finished embedding computation in 0.84 s
# Starting affinity matrix computations
# Normalization computed in 0.02 s
# Cosine similarity mat computed in 0.04 s
# Normalization computed in 0.02 s
# Cosine similarity mat computed in 0.04 s
# Finished affinity matrix computations in 0.09 s
# (Round 2) Compute nearest neighbors from coarse affmat
# Computed nearest neighbors in 0.03 s
# (Round 2) Computing affinity matrix on nearest neighbors
# Launching nearest neighbors affmat calculation job
# Job completed in: 20.18 s
# Launching nearest neighbors affmat calculation job
# Job completed in: 21.31 s
# (Round 2) Computed affinity matrix on nearest neighbors in 42.83 s
# Not applying filtering for rounds above first round
# (Round 2) Computing density adapted affmat
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 511 samples in 0.000s...
# [t-SNE] Computed neighbors for 511 samples in 0.006s...
# [t-SNE] Computed conditional probabilities for sample 511 / 511
# [t-SNE] Mean sigma: 0.239366
# (Round 2) Computing clustering
# Beginning preprocessing + Louvain
# Wrote graph to binary file in 0.0460860729218 seconds
# Running Louvain modularity optimization
# [Parallel(n_jobs=4)]: Done 144 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    2.9s finished
# Louvain completed 200 runs in 3.36443114281 seconds
# Wrote graph to binary file in 0.166689872742 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.60988
# After 2 runs, maximum modularity is Q = 0.618905
# After 48 runs, maximum modularity is Q = 0.620674
# Louvain completed 98 runs in 2.6298930645 seconds
# Preproc + Louvain took 6.2712187767 s
# Got 5 clusters after round 2
# Counts:
# {0: 142, 1: 142, 2: 111, 3: 76, 4: 40}
# (Round 2) Aggregating seqlets in each cluster
# Aggregating for cluster 0 with 142 seqlets
# Trimmed 35 out of 142
# Aggregating for cluster 1 with 142 seqlets
# Trimmed 11 out of 142
# Aggregating for cluster 2 with 111 seqlets
# Trimmed 8 out of 111
# Aggregating for cluster 3 with 76 seqlets
# Trimmed 11 out of 76
# Skipped 1 seqlets
# Aggregating for cluster 4 with 40 seqlets
# Trimmed 5 out of 40
# Got 5 clusters
# Splitting into subclusters...
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0141668319702 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00648078
# Louvain completed 21 runs in 0.380079984665 seconds
# Similarity is 0.9015728652792881; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0233640670776 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00657292
# After 2 runs, maximum modularity is Q = 0.00664009
# Louvain completed 22 runs in 0.439090013504 seconds
# Similarity is 0.9736694442372441; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.0151250362396 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00635755
# Louvain completed 21 runs in 0.381762981415 seconds
# Similarity is 0.839591507538584; is_dissimilar is False
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00688791275024 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.0097655
# Louvain completed 21 runs in 0.37880897522 seconds
# Similarity is 0.4642919634337378; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00402688980103 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00441419
# After 2 runs, maximum modularity is Q = 0.00462289
# After 5 runs, maximum modularity is Q = 0.00490376
# Louvain completed 25 runs in 0.453546047211 seconds
# Similarity is 0.6399313237444977; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00187706947327 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.001557
# After 2 runs, maximum modularity is Q = 0.00260364
# After 3 runs, maximum modularity is Q = 0.00287132
# After 6 runs, maximum modularity is Q = 0.00324068
# Louvain completed 26 runs in 0.476587057114 seconds
# Similarity is 0.5855163490914904; is_dissimilar is True
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00226497650146 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00742439
# Louvain completed 21 runs in 0.373771905899 seconds
# Similarity is 0.6117583308835968; is_dissimilar is True
# Got 4 subclusters
# Inspecting for spurious merging
# Wrote graph to binary file in 0.00337481498718 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.00446048
# After 2 runs, maximum modularity is Q = 0.00530599
# After 5 runs, maximum modularity is Q = 0.005306
# Louvain completed 25 runs in 0.440701007843 seconds
# Similarity is 0.8753803408894493; is_dissimilar is False
# Merging on 8 clusters
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 8 patterns after merging
# Performing seqlet reassignment
# Cross contin jaccard time taken: 0.28 s
# Cross contin jaccard time taken: 0.28 s
# Discarded 1 seqlets
# Skipped 4 seqlets
# Skipped 4 seqlets
# Skipped 3 seqlets
# Got 5 patterns after reassignment
# Total time taken is 102.34s

# %%
from modisco.visualization import viz_sequence
from modisco.aggregator import TrimToBestWindow

pattern_merge_hierarchy = (tfmodisco_results.metacluster_idx_to_submetacluster_results[0]
                           .seqlets_to_patterns_result.pattern_merge_hierarchy)
for node in pattern_merge_hierarchy.root_nodes:
    pattern = node.pattern.trim_to_positions_with_min_support(0.2, 20)
    background = np.array([0.25, 0.25, 0.25, 0.25])
    print(len(pattern.seqlets))
    viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"].fwd),
                                                    background=background))
    viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"].rev),
                                                    background=background))
# Out:
# Trimmed 2 out of 111
# 109
# Trimmed 9 out of 140
# 131
# Trimmed 9 out of 112
# 103
# Trimmed 0 out of 15
# 15
# Trimmed 0 out of 14
# 14
# Trimmed 1 out of 39
# 38
# Trimmed 0 out of 7
# 7
# Trimmed 2 out of 37
# 35
