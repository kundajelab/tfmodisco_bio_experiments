# %%
# !ln -s /users/amtseng/tfmodisco/motifs/SPI1/mini_100_test/ .

# %%
import numpy as np
imp_scores = np.load("mini_100_test/act_scores.npy")
onehot = np.load("mini_100_test/one_hot.npy")
hypimp_scores = np.load("mini_100_test/hyp_scores.npy")

# %%
# %matplotlib inline
from modisco.visualization import viz_sequence

viz_sequence.plot_weights(onehot[0], subticks_frequency=20)
viz_sequence.plot_weights(imp_scores[0], subticks_frequency=20)
viz_sequence.plot_weights(hypimp_scores[0], subticks_frequency=20)

# %%
import h5py
import numpy as np
# %matplotlib inline
import modisco

task_to_scores = {"task0": imp_scores}
task_to_hyp_scores = {"task0": hypimp_scores}

null_per_pos_scores = modisco.coordproducers.LaplaceNullDist(num_to_samp=5000)
tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                    #Slight modifications from the default settings
                    sliding_window_size=15,
                    flank_size=5,
                    target_seqlet_fdr=0.15,
                    seqlets_to_patterns_factory=
                     modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                        trim_to_window_size=15,
                        initial_flank_to_add=5,
                        kmer_len=5, num_gaps=1,
                        num_mismatches=0,
                        final_min_cluster_size=60)
                )(
                 task_names=["task0"],
                 contrib_scores=task_to_scores,
                 hypothetical_contribs=task_to_hyp_scores,
                 one_hot=onehot,
                 null_per_pos_scores=null_per_pos_scores)
# Out:
# TF-MoDISco is using the TensorFlow backend.
# MEMORY 0.3395584
# On task task0
# Computing windowed sums on original
# Generating null dist
# peak(mu)= -0.0004988547114265353
# Computing threshold
# Thresholds from null dist were -0.23631814114632732  and  0.260622035205597
# Final raw thresholds are -0.23631814114632732  and  0.260622035205597
# Final transformed thresholds are -0.8468134715025907  and  0.8587305699481865
# Got 459 coords
# After resolving overlaps, got 459 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.8468133715025907
# MEMORY 0.351043584
# 459 identified in total
# 2 activity patterns with support >= 100 out of 3 possible patterns
# Metacluster sizes:  [352, 107]
# Idx to activities:  {0: '1', 1: '-1'}
# MEMORY 0.351043584
# On metacluster 1
# Metacluster size 107
# Relevant tasks:  ('task0',)
# Relevant signs:  (-1,)
# WARNING: Logging before flag parsing goes to stderr.
# W1212 10:09:12.599471 140379675109120 deprecation_wrapper.py:119] From /users/avanti/modisco_private/modisco/backend/tensorflow_backend.py:87: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# kmer embedding func instantiated
# MEMORY 0.352862208
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 107
# (Round 1) Computing coarse affmat
# MEMORY 0.352862208
# Beginning embedding computation
# MEMORY 0.352862208
# Computing embeddings
# MEMORY 0.352862208
# After onehot_track_fwd and onehot_track_rev
# MEMORY 0.353062912
# data_to_embed_fwd and data_to_embed_rev instantiated
# MEMORY 0.353062912
# data_to_embed_fwd and data_to_embed_rev prepared shapes are (107, 25, 4) and (107, 25, 4)
# MEMORY 0.353062912
# data_to_embed_fwd and data_to_embed_rev normalized
# MEMORY 0.353062912
# Using TensorFlow backend.
# W1212 10:09:13.092733 140379675109120 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1212 10:09:13.093928 140379675109120 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1212 10:09:13.095121 140379675109120 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1212 10:09:13.433085 140379675109120 deprecation_wrapper.py:119] From /users/avanti/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# embedding_fwd and embedding_rev prepared
# MEMORY 1.648922624
# Finished embeddings computation - intermediate vars in scope
# MEMORY 1.648922624
# Finished embedding computation in 2.67 s
# MEMORY 1.648939008
# Starting affinity matrix computations
# MEMORY 1.648939008
# Computed normalized vectors - 1
# MEMORY 1.649491968
# Computed normalized vectors - 2
# MEMORY 1.650028544
# Normalization computed in 0.0 s
# MEMORY 1.650028544
# Computed dot product
# MEMORY 1.650417664
# Cosine similarity mat computed in 0.01 s
# MEMORY 1.650417664
# Fwd affmat computed
# MEMORY 1.650417664
# Computed normalized vectors - 1
# MEMORY 1.650417664
# Computed normalized vectors - 2
# MEMORY 1.650417664
# Normalization computed in 0.0 s
# MEMORY 1.650417664
# Computed dot product
# MEMORY 1.650417664
# Cosine similarity mat computed in 0.01 s
# MEMORY 1.650417664
# Rev affmat computed
# MEMORY 1.650417664
# Finished affinity matrix computations in 0.03 s
# MEMORY 1.650417664
# (Round 1) Compute nearest neighbors from coarse affmat
# MEMORY 1.650417664
# Computed nearest neighbors in 0.08 s
# MEMORY 1.650417664
# (Round 1) Computing affinity matrix on nearest neighbors
# MEMORY 1.650417664
# Launching nearest neighbors affmat calculation job
# MEMORY 1.650417664
# Parallel runs completed
# MEMORY 1.65562368
# Job completed in: 0.56 s
# MEMORY 1.65562368
# Launching nearest neighbors affmat calculation job
# MEMORY 1.65562368
# Parallel runs completed
# MEMORY 1.657667584
# Job completed in: 0.52 s
# MEMORY 1.657667584
# (Round 1) Computed affinity matrix on nearest neighbors in 1.21 s
# MEMORY 1.6579584
# Filtered down to 94 of 107
# (Round 1) Retained 94 rows out of 107 after filtering
# MEMORY 1.658220544
# (Round 1) Computing density adapted affmat
# MEMORY 1.658220544
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 94 samples in 0.000s...
# [t-SNE] Computed neighbors for 94 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 94 / 94
# [t-SNE] Mean sigma: 0.242427
# (Round 1) Computing clustering
# MEMORY 1.658220544
# Beginning preprocessing + Louvain
# MEMORY 1.658220544
# Wrote graph to binary file in 0.02059650421142578 seconds
# MEMORY 1.658363904
# Running Louvain modularity optimization
# MEMORY 1.658363904
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  57 tasks      | elapsed:    7.5s
# Louvain completed 200 runs in 8.39897608757019 seconds
# MEMORY 1.6587776
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    8.3s finished
# Transformed affinity matrix
# MEMORY 1.658793984
# Wrote graph to binary file in 0.008479118347167969 seconds
# MEMORY 1.658793984
# Running Louvain modularity optimization
# MEMORY 1.658793984
# After 1 runs, maximum modularity is Q = 0.766904
# MEMORY 1.65879808
# Louvain completed 51 runs in 4.033401727676392 seconds
# MEMORY 1.658806272
# Got communities, graph, Q
# MEMORY 1.658806272
# Packaged as cluster results
# MEMORY 1.658806272
# Preproc + Louvain took 12.890992403030396 s
# MEMORY 1.658806272
# Got 8 clusters after round 1
# Counts:
# {2: 17, 3: 16, 7: 3, 5: 8, 6: 6, 0: 18, 1: 17, 4: 9}
# MEMORY 1.658806272
# (Round 1) Aggregating seqlets in each cluster
# MEMORY 1.658806272
# Aggregating for cluster 0 with 18 seqlets
# MEMORY 1.658806272
# Trimmed 0 out of 18
# Aggregating for cluster 1 with 17 seqlets
# MEMORY 1.658834944
# Trimmed 0 out of 17
# Dropping cluster 1 with 17 seqlets due to sign disagreement
# Aggregating for cluster 2 with 17 seqlets
# MEMORY 1.658863616
# Trimmed 0 out of 17
# Dropping cluster 2 with 17 seqlets due to sign disagreement
# Aggregating for cluster 3 with 16 seqlets
# MEMORY 1.658871808
# Trimmed 0 out of 16
# Dropping cluster 3 with 16 seqlets due to sign disagreement
# Aggregating for cluster 4 with 9 seqlets
# MEMORY 1.658896384
# Trimmed 0 out of 9
# Aggregating for cluster 5 with 8 seqlets
# MEMORY 1.658896384
# Trimmed 0 out of 8
# Aggregating for cluster 6 with 6 seqlets
# MEMORY 1.658904576
# Trimmed 0 out of 6
# Dropping cluster 6 with 6 seqlets due to sign disagreement
# Aggregating for cluster 7 with 3 seqlets
# MEMORY 1.658916864
# Trimmed 0 out of 3
# Dropping cluster 7 with 3 seqlets due to sign disagreement
# (Round 2) num seqlets: 34
# (Round 2) Computing coarse affmat
# MEMORY 1.658925056
# Beginning embedding computation
# MEMORY 1.658925056
# Computing embeddings
# MEMORY 1.658925056
# After onehot_track_fwd and onehot_track_rev
# MEMORY 1.658925056
# data_to_embed_fwd and data_to_embed_rev instantiated
# MEMORY 1.658925056
# data_to_embed_fwd and data_to_embed_rev prepared shapes are (34, 25, 4) and (34, 25, 4)
# MEMORY 1.658925056
# data_to_embed_fwd and data_to_embed_rev normalized
# MEMORY 1.658925056
# embedding_fwd and embedding_rev prepared
# MEMORY 1.660133376
# Finished embeddings computation - intermediate vars in scope
# MEMORY 1.660133376
# Finished embedding computation in 0.18 s
# MEMORY 1.660133376
# Starting affinity matrix computations
# MEMORY 1.660133376
# Computed normalized vectors - 1
# MEMORY 1.660133376
# Computed normalized vectors - 2
# MEMORY 1.660133376
# Normalization computed in 0.01 s
# MEMORY 1.660133376
# Computed dot product
# MEMORY 1.660133376
# Cosine similarity mat computed in 0.01 s
# MEMORY 1.660133376
# Fwd affmat computed
# MEMORY 1.660133376
# Computed normalized vectors - 1
# MEMORY 1.660133376
# Computed normalized vectors - 2
# MEMORY 1.660133376
# Normalization computed in 0.0 s
# MEMORY 1.660133376
# Computed dot product
# MEMORY 1.660133376
# Cosine similarity mat computed in 0.01 s
# MEMORY 1.660133376
# Rev affmat computed
# MEMORY 1.660133376
# Finished affinity matrix computations in 0.03 s
# MEMORY 1.660133376
# (Round 2) Compute nearest neighbors from coarse affmat
# MEMORY 1.660133376
# Computed nearest neighbors in 0.09 s
# MEMORY 1.660133376
# (Round 2) Computing affinity matrix on nearest neighbors
# MEMORY 1.660133376
# Launching nearest neighbors affmat calculation job
# MEMORY 1.660133376
# Parallel runs completed
# MEMORY 1.660608512
# Job completed in: 0.33 s
# MEMORY 1.660608512
# Launching nearest neighbors affmat calculation job
# MEMORY 1.660608512
# Parallel runs completed
# MEMORY 1.66086656
# Job completed in: 0.34 s
# MEMORY 1.66086656
# (Round 2) Computed affinity matrix on nearest neighbors in 0.8 s
# MEMORY 1.66086656
# Not applying filtering for rounds above first round
# MEMORY 1.66086656
# (Round 2) Computing density adapted affmat
# MEMORY 1.66086656
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 34 samples in 0.000s...
# [t-SNE] Computed neighbors for 34 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 34 / 34
# [t-SNE] Mean sigma: 0.353651
# (Round 2) Computing clustering
# MEMORY 1.660891136
# Beginning preprocessing + Louvain
# MEMORY 1.660891136
# Wrote graph to binary file in 0.005736112594604492 seconds
# MEMORY 1.660891136
# Running Louvain modularity optimization
# MEMORY 1.660891136
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Louvain completed 200 runs in 1.446160078048706 seconds
# MEMORY 1.66090752
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    1.4s finished
# Transformed affinity matrix
# MEMORY 1.660919808
# Wrote graph to binary file in 0.004234790802001953 seconds
# MEMORY 1.660919808
# Running Louvain modularity optimization
# MEMORY 1.660919808
# After 1 runs, maximum modularity is Q = 0.582353
# MEMORY 1.660928
# Louvain completed 51 runs in 3.9346601963043213 seconds
# MEMORY 1.660932096
# Got communities, graph, Q
# MEMORY 1.660932096
# Packaged as cluster results
# MEMORY 1.660932096
# Preproc + Louvain took 5.734374046325684 s
# MEMORY 1.660932096
# Got 4 clusters after round 2
# Counts:
# {1: 12, 0: 13, 3: 2, 2: 7}
# MEMORY 1.660932096
# (Round 2) Aggregating seqlets in each cluster
# MEMORY 1.660932096
# Aggregating for cluster 0 with 13 seqlets
# MEMORY 1.660932096
# Trimmed 0 out of 13
# Dropping cluster 0 with 13 seqlets due to sign disagreement
# Aggregating for cluster 1 with 12 seqlets
# MEMORY 1.660932096
# Trimmed 0 out of 12
# Aggregating for cluster 2 with 7 seqlets
# MEMORY 1.660932096
# Trimmed 0 out of 7
# Aggregating for cluster 3 with 2 seqlets
# MEMORY 1.660899328
# Trimmed 0 out of 2
# Got 3 clusters
# Splitting into subclusters...
# MEMORY 1.660899328
# Merging on 3 clusters
# MEMORY 1.660899328
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 3 patterns after merging
# MEMORY 1.6608256
# Performing seqlet reassignment
# MEMORY 1.6608256
# Got 0 patterns after reassignment
# MEMORY 1.6608256
# Total time taken is 25.74s
# MEMORY 1.6608256
# On metacluster 0
# Metacluster size 352
# Relevant tasks:  ('task0',)
# Relevant signs:  (1,)
# kmer embedding func instantiated
# MEMORY 1.660923904
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 352
# (Round 1) Computing coarse affmat
# MEMORY 1.660977152
# Beginning embedding computation
# MEMORY 1.660977152
# Computing embeddings
# MEMORY 1.660977152
# After onehot_track_fwd and onehot_track_rev
# MEMORY 1.660977152
# data_to_embed_fwd and data_to_embed_rev instantiated
# MEMORY 1.660977152
# data_to_embed_fwd and data_to_embed_rev prepared shapes are (352, 25, 4) and (352, 25, 4)
# MEMORY 1.660977152
# data_to_embed_fwd and data_to_embed_rev normalized
# MEMORY 1.660977152
# embedding_fwd and embedding_rev prepared
# MEMORY 1.665425408
# Finished embeddings computation - intermediate vars in scope
# MEMORY 1.665425408
# Finished embedding computation in 0.24 s
# MEMORY 1.665425408
# Starting affinity matrix computations
# MEMORY 1.665425408
# Computed normalized vectors - 1
# MEMORY 1.667510272
# Computed normalized vectors - 2
# MEMORY 1.668861952
# Normalization computed in 0.01 s
# MEMORY 1.668861952
# Computed dot product
# MEMORY 1.669206016
# Cosine similarity mat computed in 0.02 s
# MEMORY 1.669206016
# Fwd affmat computed
# MEMORY 1.669206016
# Computed normalized vectors - 1
# MEMORY 1.669206016
# Computed normalized vectors - 2
# MEMORY 1.669726208
# Normalization computed in 0.01 s
# MEMORY 1.669726208
# Computed dot product
# MEMORY 1.669726208
# Cosine similarity mat computed in 0.01 s
# MEMORY 1.669726208
# Rev affmat computed
# MEMORY 1.669726208
# Finished affinity matrix computations in 0.04 s
# MEMORY 1.669726208
# (Round 1) Compute nearest neighbors from coarse affmat
# MEMORY 1.669726208
# Computed nearest neighbors in 0.09 s
# MEMORY 1.669726208
# (Round 1) Computing affinity matrix on nearest neighbors
# MEMORY 1.669726208
# Launching nearest neighbors affmat calculation job
# MEMORY 1.670053888
# Parallel runs completed
# MEMORY 1.683869696
# Job completed in: 2.49 s
# MEMORY 1.683869696
# Launching nearest neighbors affmat calculation job
# MEMORY 1.683869696
# Parallel runs completed
# MEMORY 1.687662592
# Job completed in: 2.46 s
# MEMORY 1.687662592
# (Round 1) Computed affinity matrix on nearest neighbors in 5.13 s
# MEMORY 1.687662592
# Filtered down to 285 of 352
# (Round 1) Retained 285 rows out of 352 after filtering
# MEMORY 1.6878592
# (Round 1) Computing density adapted affmat
# MEMORY 1.6878592
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 285 samples in 0.000s...
# [t-SNE] Computed neighbors for 285 samples in 0.004s...
# [t-SNE] Computed conditional probabilities for sample 285 / 285
# [t-SNE] Mean sigma: 0.236858
# (Round 1) Computing clustering
# MEMORY 1.6878592
# Beginning preprocessing + Louvain
# MEMORY 1.6878592
# Wrote graph to binary file in 0.042642831802368164 seconds
# MEMORY 1.6878592
# Running Louvain modularity optimization
# MEMORY 1.6878592
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Louvain completed 200 runs in 1.727710485458374 seconds
# MEMORY 1.687875584
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    1.6s finished
# Transformed affinity matrix
# MEMORY 1.687883776
# Wrote graph to binary file in 0.08485841751098633 seconds
# MEMORY 1.687883776
# Running Louvain modularity optimization
# MEMORY 1.687883776
# After 1 runs, maximum modularity is Q = 0.522592
# MEMORY 1.687887872
# Louvain completed 51 runs in 4.258985280990601 seconds
# MEMORY 1.687887872
# Got communities, graph, Q
# MEMORY 1.687887872
# Packaged as cluster results
# MEMORY 1.687887872
# Preproc + Louvain took 6.610066652297974 s
# MEMORY 1.687887872
# Got 7 clusters after round 1
# Counts:
# {2: 52, 1: 62, 3: 27, 4: 20, 5: 11, 0: 103, 6: 10}
# MEMORY 1.687887872
# (Round 1) Aggregating seqlets in each cluster
# MEMORY 1.687887872
# Aggregating for cluster 0 with 103 seqlets
# MEMORY 1.687887872
# Trimmed 22 out of 103
# Aggregating for cluster 1 with 62 seqlets
# MEMORY 1.688129536
# Trimmed 3 out of 62
# Skipped 2 seqlets
# Aggregating for cluster 2 with 52 seqlets
# MEMORY 1.688129536
# Trimmed 6 out of 52
# Aggregating for cluster 3 with 27 seqlets
# MEMORY 1.688129536
# Trimmed 0 out of 27
# Aggregating for cluster 4 with 20 seqlets
# MEMORY 1.688170496
# Trimmed 4 out of 20
# Aggregating for cluster 5 with 11 seqlets
# MEMORY 1.688174592
# Trimmed 0 out of 11
# Aggregating for cluster 6 with 10 seqlets
# MEMORY 1.688174592
# Trimmed 0 out of 10
# Skipped 3 seqlets
# (Round 2) num seqlets: 234
# (Round 2) Computing coarse affmat
# MEMORY 1.688199168
# Beginning embedding computation
# MEMORY 1.688199168
# Computing embeddings
# MEMORY 1.688199168
# After onehot_track_fwd and onehot_track_rev
# MEMORY 1.688199168
# data_to_embed_fwd and data_to_embed_rev instantiated
# MEMORY 1.688199168
# data_to_embed_fwd and data_to_embed_rev prepared shapes are (234, 25, 4) and (234, 25, 4)
# MEMORY 1.688199168
# data_to_embed_fwd and data_to_embed_rev normalized
# MEMORY 1.688199168
# embedding_fwd and embedding_rev prepared
# MEMORY 1.688199168
# Finished embeddings computation - intermediate vars in scope
# MEMORY 1.688199168
# Finished embedding computation in 0.13 s
# MEMORY 1.688199168
# Starting affinity matrix computations
# MEMORY 1.688199168
# Computed normalized vectors - 1
# MEMORY 1.688199168
# Computed normalized vectors - 2
# MEMORY 1.688199168
# Normalization computed in 0.0 s
# MEMORY 1.688199168
# Computed dot product
# MEMORY 1.688199168
# Cosine similarity mat computed in 0.01 s
# MEMORY 1.688199168
# Fwd affmat computed
# MEMORY 1.688199168
# Computed normalized vectors - 1
# MEMORY 1.688199168
# Computed normalized vectors - 2
# MEMORY 1.688199168
# Normalization computed in 0.0 s
# MEMORY 1.688203264
# Computed dot product
# MEMORY 1.688203264
# Cosine similarity mat computed in 0.01 s
# MEMORY 1.688203264
# Rev affmat computed
# MEMORY 1.688203264
# Finished affinity matrix computations in 0.03 s
# MEMORY 1.688203264
# (Round 2) Compute nearest neighbors from coarse affmat
# MEMORY 1.688203264
# Computed nearest neighbors in 0.07 s
# MEMORY 1.688203264
# (Round 2) Computing affinity matrix on nearest neighbors
# MEMORY 1.688203264
# Launching nearest neighbors affmat calculation job
# MEMORY 1.688203264
# Parallel runs completed
# MEMORY 1.688915968
# Job completed in: 1.25 s
# MEMORY 1.688915968
# Launching nearest neighbors affmat calculation job
# MEMORY 1.688915968
# Parallel runs completed
# MEMORY 1.68998912
# Job completed in: 1.37 s
# MEMORY 1.68998912
# (Round 2) Computed affinity matrix on nearest neighbors in 2.77 s
# MEMORY 1.68998912
# Not applying filtering for rounds above first round
# MEMORY 1.68998912
# (Round 2) Computing density adapted affmat
# MEMORY 1.68998912
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 234 samples in 0.001s...
# [t-SNE] Computed neighbors for 234 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 234 / 234
# [t-SNE] Mean sigma: 0.250269
# (Round 2) Computing clustering
# MEMORY 1.68998912
# Beginning preprocessing + Louvain
# MEMORY 1.68998912
# Wrote graph to binary file in 0.03749847412109375 seconds
# MEMORY 1.68998912
# Running Louvain modularity optimization
# MEMORY 1.68998912
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Louvain completed 200 runs in 1.6068179607391357 seconds
# MEMORY 1.690025984
# [Parallel(n_jobs=4)]: Done 200 out of 200 | elapsed:    1.5s finished
# Transformed affinity matrix
# MEMORY 1.690042368
# Wrote graph to binary file in 0.035257816314697266 seconds
# MEMORY 1.690042368
# Running Louvain modularity optimization
# MEMORY 1.690042368
# After 1 runs, maximum modularity is Q = 0.704551
# MEMORY 1.690046464
# Louvain completed 51 runs in 4.137033224105835 seconds
# MEMORY 1.690046464
# Got communities, graph, Q
# MEMORY 1.690046464
# Packaged as cluster results
# MEMORY 1.690046464
# Preproc + Louvain took 6.18681001663208 s
# MEMORY 1.690046464
# Got 9 clusters after round 2
# Counts:
# {6: 10, 7: 8, 2: 34, 3: 29, 0: 62, 1: 35, 5: 22, 4: 27, 8: 7}
# MEMORY 1.690046464
# (Round 2) Aggregating seqlets in each cluster
# MEMORY 1.690046464
# Aggregating for cluster 0 with 62 seqlets
# MEMORY 1.690046464
# Trimmed 2 out of 62
# Aggregating for cluster 1 with 35 seqlets
# MEMORY 1.690107904
# Trimmed 8 out of 35
# Aggregating for cluster 2 with 34 seqlets
# MEMORY 1.690112
# Trimmed 6 out of 34
# Aggregating for cluster 3 with 29 seqlets
# MEMORY 1.690112
# Trimmed 3 out of 29
# Aggregating for cluster 4 with 27 seqlets
# MEMORY 1.690112
# Trimmed 2 out of 27
# Aggregating for cluster 5 with 22 seqlets
# MEMORY 1.690112
# Trimmed 3 out of 22
# Aggregating for cluster 6 with 10 seqlets
# MEMORY 1.69013248
# Trimmed 0 out of 10
# Aggregating for cluster 7 with 8 seqlets
# MEMORY 1.690165248
# Trimmed 0 out of 8
# Aggregating for cluster 8 with 7 seqlets
# MEMORY 1.690165248
# Trimmed 0 out of 7
# Got 9 clusters
# Splitting into subclusters...
# MEMORY 1.690165248
# Inspecting for spurious merging
# Wrote graph to binary file in 0.009525060653686523 seconds
# MEMORY 1.690177536
# Running Louvain modularity optimization
# MEMORY 1.690177536
# After 1 runs, maximum modularity is Q = -0.0119437
# MEMORY 1.690177536
# After 4 runs, maximum modularity is Q = 0.00569475
# MEMORY 1.690177536
# After 9 runs, maximum modularity is Q = 0.00569794
# MEMORY 1.690177536
# Louvain completed 29 runs in 2.4620699882507324 seconds
# MEMORY 1.690177536
# Similarity is 0.4387625819270081; is_dissimilar is True
# Got 2 subclusters
# Merging on 10 clusters
# MEMORY 1.690181632
# On merging iteration 1
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Collapsing 5 & 7 with prob 0.0003125014932360283 and sim 0.9834155129807993
# Collapsing 7 & 8 with prob 1.312136103049354e-05 and sim 0.9715616487151264
# Collapsing 5 & 8 with prob 2.6235462731057182e-05 and sim 0.9715387415341703
# Collapsing 3 & 5 with prob 0.0001718957084408371 and sim 0.9533128514115189
# Collapsing 2 & 5 with prob 0.0005939630446839967 and sim 0.9478999411525271
# Collapsing 3 & 6 with prob 0.00017162361238266813 and sim 0.9313082204064164
# Collapsing 2 & 3 with prob 0.00014973884818043686 and sim 0.9247804812051669
# Collapsing 5 & 6 with prob 0.00022046396945579253 and sim 0.9237042989826075
# Collapsing 3 & 4 with prob 6.875407061919306e-05 and sim 0.9178801439379908
# Aborting collapse as 2 & 4 have prob 1.0091658320822133e-05 and sim 0.8102400878537779
# Collapsing 4 & 5 with prob 0.00011201185278624208 and sim 0.9049334480960337
# Aborting collapse as 2 & 4 have prob 1.0091658320822133e-05 and sim 0.8102400878537779
# Collapsing 2 & 6 with prob 3.6649712756509454e-05 and sim 0.8969903611169914
# Collapsing 4 & 6 with prob 2.6028872721851453e-05 and sim 0.8851029777310327
# Aborting collapse as 2 & 4 have prob 1.0091658320822133e-05 and sim 0.8102400878537779
# Trimmed 0 out of 31
# Trimmed 1 out of 33
# Trimmed 0 out of 60
# Trimmed 0 out of 85
# Trimmed 0 out of 104
# On merging iteration 2
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Collapsing 0 & 3 with prob 0.0005089882321493762 and sim 0.9197772636420806
# Trimmed 0 out of 125
# On merging iteration 3
# Computing pattern to seqlet distances
# Computing pattern to pattern distances
# Got 4 patterns after merging
# MEMORY 1.690796032
# Performing seqlet reassignment
# MEMORY 1.690796032
# Cross contin jaccard time taken: 0.03 s
# Cross contin jaccard time taken: 0.03 s
# Discarded 62 seqlets
# Got 1 patterns after reassignment
# MEMORY 1.692102656
# Total time taken is 33.29s
# MEMORY 1.692102656

# %%
from modisco.visualization import viz_sequence

for metacluster_idx in tfmodisco_results.metacluster_idx_to_submetacluster_results.keys():
    print("metacluster_idx",metacluster_idx)
    submetacluster_results = tfmodisco_results.metacluster_idx_to_submetacluster_results[metacluster_idx]
    patterns = submetacluster_results.seqlets_to_patterns_result.patterns
    for idx,pattern in enumerate(patterns):
        print("Pattern number",idx)
        viz_sequence.plot_weights(pattern["task0_contrib_scores"].fwd)
        viz_sequence.plot_weights(pattern["task0_hypothetical_contribs"].fwd)
# Out:
# metacluster_idx 1
# metacluster_idx 0
# Pattern number 0
